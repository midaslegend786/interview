# %%
# importing relevant python packages
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# importing csv file
df_interview = pd.read_csv('Interview.csv')

# %%
# for visualisation
df_interview.head()
# Out:
#         Country Or Region Name Country Code Currency Unit Country Region  \
# 0  Africa Eastern and Southern          AFE           NaN            NaN
# 1  Africa Eastern and Southern          AFE           NaN            NaN
# 2  Africa Eastern and Southern          AFE           NaN            NaN
# 3  Africa Eastern and Southern          AFE           NaN            NaN
# 4  Africa Eastern and Southern          AFE           NaN            NaN
#
#   Country Income Group                                 Topic  \
# 0                  NaN  Environment: Energy production & use
# 1                  NaN  Environment: Energy production & use
# 2                  NaN  Environment: Energy production & use
# 3                  NaN  Environment: Energy production & use
# 4                  NaN  Environment: Energy production & use
#
#                                       Indicator Name       2000       2001  \
# 0  Access to clean fuels and technologies for coo...  11.435351  11.805706
# ...

# %%
# dropping columns
df_interview = df_interview.drop(columns=['Country Income Group'])

# filtering dataframe
# df_interview = df_interview[(df_interview['Topic']=='Economic Policy & Debt: Balance of payments: Capital & financial account')]

# for visualisation
df_interview.head()
# Out:
#         Country Or Region Name Country Code Currency Unit Country Region  \
# 0  Africa Eastern and Southern          AFE           NaN            NaN
# 1  Africa Eastern and Southern          AFE           NaN            NaN
# 2  Africa Eastern and Southern          AFE           NaN            NaN
# 3  Africa Eastern and Southern          AFE           NaN            NaN
# 4  Africa Eastern and Southern          AFE           NaN            NaN
#
#                                   Topic  \
# 0  Environment: Energy production & use
# 1  Environment: Energy production & use
# 2  Environment: Energy production & use
# 3  Environment: Energy production & use
# 4  Environment: Energy production & use
#
#                                       Indicator Name       2000       2001  \
# 0  Access to clean fuels and technologies for coo...  11.435351  11.805706
# 1  Access to clean fuels and technologies for coo...   3.500037   3.692771
# ...

# %%
# checking the size of dataframe
df_interview.shape
# Out:
# (384370, 27)

# %%
# renaming columns
df_interview = df_interview.rename(columns={'Country Or Region Name': 'Country_Or_Region_Name', 'Country Code': 'Country_Code', 
                                           'Currency Unit': 'Currency_Unit', 'Country Region': 'Country_Region', 
                                            'Indicator Name': 'Indicator_Name', '2000': 'Year_2000', '2001': 'Year_2001', 
                                            '2002': 'Year_2002', '2003': 'Year_2003', '2004': 'Year_2004', '2005': 'Year_2005',
                                           '2006': 'Year_2006', '2007': 'Year_2007', '2008': 'Year_2008', '2009': 'Year_2009',
                                           '2010': 'Year_2010', '2011': 'Year_2011', '2012': 'Year_2012', '2013': 'Year_2013',
                                           '2014': 'Year_2014', '2015': 'Year_2015', '2016': 'Year_2016', '2017': 'Year_2017', 
                                           '2018': 'Year_2018', '2019': 'Year_2019', '2020': 'Year_2020'})

# keeping countries that has US Dollar or Euro
cols = ['Currency_Unit']
df_interview = df_interview.loc[df_interview[cols].apply(lambda x: x.str.contains(r'U.S. dollar|Euro')).any(axis=1)]
# df_interview = df_interview[df_interview["Currency_Unit"].str.contains(r'US Dollar|Euro')]

# dropping rows that has NaN values
df_interview = df_interview.dropna(how='any',axis=0)
# df_interview = df_interview.dropna()
# df_interview = df_interview.dropna(subset=['Year_2000', 'Year_2001', 'Year_2002', 'Year_2003', 'Year_2004', 'Year_2005', 'Year_2006',
#                                           'Year_2007', 'Year_2008', 'Year_2009', 'Year_2010', 'Year_2011', 'Year_2012', 'Year_2013',
#                                           'Year_2014', 'Year_2015', 'Year_2016', 'Year_2017', 'Year_2018', 'Year_2019', 'Year_2020'])


df_interview['Year_2001']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2001'].astype(int)*
                             eur_to_usd, df_interview['Year_2001'])
df_interview['Year_2002']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2002'].astype(int)*
                             eur_to_usd, df_interview['Year_2002'])
df_interview['Year_2003']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2003'].astype(int)*
                             eur_to_usd, df_interview['Year_2003'])
df_interview['Year_2004']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2004'].astype(int)*
                             eur_to_usd, df_interview['Year_2004'])
df_interview['Year_2005']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2005'].astype(int)*
                             eur_to_usd, df_interview['Year_2005'])
df_interview['Year_2006']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2006'].astype(int)*
                             eur_to_usd, df_interview['Year_2006'])
df_interview['Year_2007']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2007'].astype(int)*
                             eur_to_usd, df_interview['Year_2007'])
df_interview['Year_2008']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2008'].astype(int)*
                             eur_to_usd, df_interview['Year_2008'])
df_interview['Year_2009']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2009'].astype(int)*
                             eur_to_usd, df_interview['Year_2009'])
df_interview['Year_2010']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2010'].astype(int)*
                             eur_to_usd, df_interview['Year_2010'])
df_interview['Year_2011']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2011'].astype(int)*
                             eur_to_usd, df_interview['Year_2011'])
df_interview['Year_2012']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2012'].astype(int)*
                             eur_to_usd, df_interview['Year_2012'])
df_interview['Year_2013']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2013'].astype(int)*
                             eur_to_usd, df_interview['Year_2013'])
df_interview['Year_2014']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2014'].astype(int)*
                             eur_to_usd, df_interview['Year_2014'])
df_interview['Year_2015']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2015'].astype(int)*
                             eur_to_usd, df_interview['Year_2015'])
df_interview['Year_2016']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2016'].astype(int)*
                             eur_to_usd, df_interview['Year_2016'])
df_interview['Year_2017']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2017'].astype(int)*
                             eur_to_usd, df_interview['Year_2017'])
df_interview['Year_2018']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2018'].astype(int)*
                             eur_to_usd, df_interview['Year_2018'])
df_interview['Year_2019']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2019'].astype(int)*
                             eur_to_usd, df_interview['Year_2019'])
df_interview['Year_2020']=np.where(df_interview.Currency_Unit.str.contains('Euro'), df_interview['Year_2020'].astype(int)*
                             eur_to_usd, df_interview['Year_2020'])

#df_interview[['Year_2000', 'Year_2001', 'Year_2002', 'Year_2003', 'Year_2004', 'Year_2005', 'Year_2006',
#              'Year_2007', 'Year_2008', 'Year_2009', 'Year_2010', 'Year_2011', 'Year_2012', 'Year_2013',
#              'Year_2014', 'Year_2015', 'Year_2016', 'Year_2017', 'Year_2018', 'Year_2019', 'Year_2020'
#             ]] = df_interview.query('Currency_Unit=="U.S. dollar"')[['Year_2000', 'Year_2001', 'Year_2002', 'Year_2003',                             
#                'Year_2004', 'Year_2005', 'Year_2006', 'Year_2007', 'Year_2008', 'Year_2009', 'Year_2010', 'Year_2011', 
#                'Year_2012', 'Year_2013', 'Year_2014', 'Year_2015', 'Year_2016', 'Year_2017', 'Year_2018', 'Year_2019', 
#                'Year_2020']]*eur_to_usd

# for visualisation
df_interview.head()
# Out:
#       Country_Or_Region_Name Country_Code Currency_Unit       Country_Region  \
# 75532         American Samoa          ASM   U.S. dollar  East Asia & Pacific
# 75533         American Samoa          ASM   U.S. dollar  East Asia & Pacific
# 75534         American Samoa          ASM   U.S. dollar  East Asia & Pacific
# 75598         American Samoa          ASM   U.S. dollar  East Asia & Pacific
# 75599         American Samoa          ASM   U.S. dollar  East Asia & Pacific
#
#                                              Topic  \
# 75532  Private Sector & Trade: Trade price indices
# 75533        Private Sector & Trade: Trade indexes
# 75534        Private Sector & Trade: Trade indexes
# 75598                        Environment: Land use
# 75599                        Environment: Land use
#
#                              Indicator_Name  Year_2000   Year_2001  \
# 75532  Export unit value index (2000 = 100)     100.00   95.610665
# ...

# %%
# checking the size of dataframe
df_interview.shape
# Out:
# (12565, 27)

# %%
# list of values of 'Marks' column
currency_list = df_interview['Currency_Unit'].unique()

# show the list
print(currency_list)
# Out:
# ['U.S. dollar' 'Euro']

# %%
# list of values of 'Marks' column
indicator_list = df_interview['Indicator_Name'].unique()

# show the list
print(indicator_list)
# Out:
# ['Export unit value index (2000 = 100)' 'Export value index (2000 = 100)'
#  'Export volume index (2000 = 100)' 'Forest area (% of land area)'
#  'Forest area (sq. km)' 'Import unit value index (2000 = 100)'
#  'Import value index (2000 = 100)' 'Import volume index (2000 = 100)'
#  'Incidence of tuberculosis (per 100,000 people)' 'Land area (sq. km)'
#  'Merchandise exports (current US$)'
#  'Merchandise exports by the reporting economy (current US$)'
#  'Merchandise exports by the reporting economy, residual (% of total merchandise exports)'
#  'Merchandise exports to economies in the Arab World (% of total merchandise exports)'
#  'Merchandise exports to high-income economies (% of total merchandise exports)'
#  'Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports)'
#  'Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)'
# ...

# %%
# exporting dataframe to bigquery
from pandas.io import gbq
df_interview.to_gbq(destination_table='world_economic_data.Interview_2', project_id='my-project-interview-52670', 
                    if_exists='fail')

# %%
# exporting csv file
df_interview.to_csv(r'C:\Users\jpatel6/Downloads\Interview_2_export.csv', index=False)
